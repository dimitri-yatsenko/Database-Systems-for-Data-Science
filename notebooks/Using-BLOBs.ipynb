# %%
import datajoint as dj

# %%
schema = dj.Schema('dimitri_blobs')
schema.drop()
schema = dj.Schema('dimitri_blobs')
# Out:
# [2022-10-18 23:44:18,544][INFO]: Connecting dimitri@db.ust-data-sci.net:3306
# [2022-10-18 23:44:19,650][INFO]: Connected dimitri@db.ust-data-sci.net:3306
# Proceed to delete entire schema `dimitri_blobs`? [yes, No]: yes

# %%
@schema
class Student(dj.Manual):
    definition = """
    student_id : int 
    ---
    custom_info : longblob
    """

# %%
dj.config['enable_python_native_blobs'] = True

# %%
Student.insert1((2, [1, 2, 3, 4]))

# %%
Student()
# Out:
# *student_id    custom_inf
# +------------+ +--------+
# 2              =BLOB=
#  (Total: 1)

# %%
Student.fetch(as_dict=True)
# Out:
# [{'student_id': 2, 'custom_info': [1, 2, 3, 4]}]

# %%
s = dj.blob.pack({1, 2, 3, 4})
dj.blob.unpack(s)
# Out:
# {1, 2, 3, 4}

# %%
import json
import numpy as np

# %%
a = {'array':  [1, 2, 3, 4], 1: "one"}

# %%
blob = json.dumps(a)

# %%
blob
# Out:
# '{"array": [1, 2, 3, 4], "1": "one"}'

# %%
json.loads(blob)
# Out:
# {'array': [1, 2, 3, 4], '1': 'one'}

# %%
import numpy as np

# %%
# cannot serialize numeric arrays
json.dumps(np.random.randn(3, 4))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 2>()
#       1 # cannot serialize numeric arrays
# ----> 2 json.dumps(np.random.randn(3, 4))
#
# File ~/opt/miniconda3/envs/benv/lib/python3.10/json/__init__.py:231, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     226 # cached encoder
#     227 if (not skipkeys and ensure_ascii and
#     228     check_circular and allow_nan and
#     229     cls is None and indent is None and separators is None and
#     230     default is None and not sort_keys and not kw):
# --> 231     return _default_encoder.encode(obj)
#     232 if cls is None:
#     233     cls = JSONEncoder
#
# File ~/opt/miniconda3/envs/benv/lib/python3.10/json/encoder.py:199, in JSONEncoder.encode(self, o)
#     195         return encode_basestring(o)
# ...

# %%
import pickle

# %%
import marshal

# %%
help(marshal)
# Out:
# Help on built-in module marshal:
#
# NAME
#     marshal
#
# MODULE REFERENCE
#     https://docs.python.org/3.10/library/marshal.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This module contains functions that can read and write Python values in
#     a binary format. The format is specific to Python, but independent of
#     machine architecture issues.
#
#     Not all Python object types are supported; in general, only objects
#     whose value is independent from a particular invocation of Python can be
#     written and read by this module. The following types are supported:
#     None, integers, floating point numbers, strings, bytes, bytearrays,
# ...

# %%
a = np.array([1, 2, 3])
blob = pickle.dumps(a)
pickle.loads(blob)
# Out:
# array([1, 2, 3])

# %%
import os
import requests
import imageio
import datajoint as dj

# %%
def download_file(url, local_file=None):
    local_file = local_file or os.path.join(os.path.abspath('.'), url.split('/')[-1])
    with open(local_file, 'wb') as f:
        f.write(requests.get(url).content)
    return local_file

# %%
file = download_file(
    "https://upload.wikimedia.org/wikipedia/commons/thumb/c/cc/Kaohsiung_Taiwan_Kaohsiung-Confucius-Temple-01.jpg/800px-Kaohsiung_Taiwan_Kaohsiung-Confucius-Temple-01.jpg")

# %%
img = imageio.v3.imread(file)

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
plt.imshow(img)

# %%
{'picture': img, 'description': 'Temple in Taiwan'}
# Out:
# {'picture': array([[[ 64, 118, 156],
#          [ 62, 116, 154],
#          [ 60, 113, 153],
#          ...,
#          [ 51, 121, 173],
#          [ 51, 121, 173],
#          [ 51, 121, 173]],
#
#         [[ 70, 124, 162],
#          [ 68, 122, 160],
#          [ 66, 119, 159],
#          ...,
#          [ 52, 122, 174],
#          [ 52, 122, 174],
#          [ 52, 122, 174]],
#
#         [[ 70, 123, 163],
#          [ 70, 123, 163],
#          [ 70, 123, 163],
#          ...,
#          [ 54, 121, 174],
#          [ 54, 121, 174],
#          [ 54, 121, 174]],
#
#         ...,
#
#         [[185, 187, 176],
#          [186, 188, 177],
#          [188, 190, 179],
#          ...,
#          [199, 199, 187],
#          [196, 196, 184],
#          [193, 193, 181]],
#
#         [[199, 203, 189],
#          [197, 201, 187],
#          [194, 198, 184],
#          ...,
#          [207, 207, 195],
#          [201, 201, 189],
#          [201, 201, 189]],
#
#         [[193, 197, 183],
# ...

# %%
@schema
class Image(dj.Manual):
    definition = """
    image_name : varchar(12)
    ---
    image_description : varchar(100)
    image : longblob    
    """

# %%
Image.insert1(
    dict(image_name='temple', 
         image_description="temple from wikimedia commons", 
         image=img))

# %%
Image()
# Out:
# *image_name    image_descript image
# +------------+ +------------+ +--------+
# temple         temple from wi =BLOB=
#  (Total: 1)

# %%
dj.blob.pack(img)
# Out:
# b'ZL123\x00\xedz\x10\x00\x00\x00\x00\x00x\x9c\x94\x9c\x07@Tg\xd6\xfe1\x1a\xb1\x02\xd2\x04D\xc4\x1a5&\xb1+\xa2\xf4\x0eJ/\xc30\xbd0La\x1a3\xc3\xd0\xcb\xd0\xbb\xd8[z\xdfl\x9a\x8560}\xe6\xce\x9d\x02\xa8\x89\x9bl6\x9b^\xad\x89\xd1\x18#\xff\xf3\x0e\x92\xf2\xed\xee\xf7\xed\xffB\xa8\x99\x19\xbc\xbf{\xcey\x9e\xf7\x9c\xf7\n\x08\x02\xb7\xe8\xd9n\xd3\x87n\xd6\xf4\xe7\xd0\x87?\x98\xf9\xf9\xfc\x87\x9f\xa3\x12\x12b\xe3\x13\x12\x12\x93\xe2\xd2\xf2\n\xc9L:%\xbb\x80\xc1\x16\xc8\xe4\xe5\xe5\xca\x8a\x8a\x8arE\x99\xac\\!++\x93K\xc5"\xa1PZ\xd5\xd4\xd2\xde\xdd\xd3\x03\xef=\xdd\x1d\xed\xad-M\r5\xd5Jy\x99L\xa1,\x93\x95\x89\xa5r\xb9D\xc8a2ybq\xa9H(`S\xc8\x14RA\x01\x81P\x90\x9f\x9fOgP\x8a\x88D2\x8dB\xa1\x0b+\xab\xab\x1b\xeaj\x95\x12yC[KskkkScC\x83JU_SYY\xa1\xac\xaeo\xa8\xabojijn\xe9\xe8\xec\x82\xd7\xe9\xeb\xebu\x1d]]]\x9d\xed\xedm\x1d\xddpt\xa1\xa3\x1b\xfd\x1d\xdd]\x07\xfb\\G\xef\xc3\xff\xad\x07\xfd\xaa\xc7u\xf4\xf5\x1d<\xd8\xdf\x7f\xb0\xe3U\t\xa1\xa1\xec\xb9\xde\xd6\xfe\xa6w\xbf\xba\xf8\xf7\x89\xa9~Bw\xff\x91
# ...

# %%
Image.insert1(
    ('python obj', 'a dict', 
     {'picture': img, 'description': 'frogs'}))

# %%
Image()
# Out:
# *image_name    image_descript image
# +------------+ +------------+ +--------+
# python obj     a dict         =BLOB=
# temple         temple from wi =BLOB=
#  (Total: 2)

# %%
r = Image.fetch('image')

# %%
r[0]
# Out:
# {'picture': array([[[ 64, 118, 156],
#          [ 62, 116, 154],
#          [ 60, 113, 153],
#          ...,
#          [ 51, 121, 173],
#          [ 51, 121, 173],
#          [ 51, 121, 173]],
#
#         [[ 70, 124, 162],
#          [ 68, 122, 160],
#          [ 66, 119, 159],
#          ...,
#          [ 52, 122, 174],
#          [ 52, 122, 174],
#          [ 52, 122, 174]],
#
#         [[ 70, 123, 163],
#          [ 70, 123, 163],
#          [ 70, 123, 163],
#          ...,
#          [ 54, 121, 174],
#          [ 54, 121, 174],
#          [ 54, 121, 174]],
#
#         ...,
#
#         [[185, 187, 176],
#          [186, 188, 177],
#          [188, 190, 179],
#          ...,
#          [199, 199, 187],
#          [196, 196, 184],
#          [193, 193, 181]],
#
#         [[199, 203, 189],
#          [197, 201, 187],
#          [194, 198, 184],
#          ...,
#          [207, 207, 195],
#          [201, 201, 189],
#          [201, 201, 189]],
#
#         [[193, 197, 183],
# ...

# %%
r[1]
# Out:
# array([[[ 64, 118, 156],
#         [ 62, 116, 154],
#         [ 60, 113, 153],
#         ...,
#         [ 51, 121, 173],
#         [ 51, 121, 173],
#         [ 51, 121, 173]],
#
#        [[ 70, 124, 162],
#         [ 68, 122, 160],
#         [ 66, 119, 159],
#         ...,
#         [ 52, 122, 174],
#         [ 52, 122, 174],
#         [ 52, 122, 174]],
#
#        [[ 70, 123, 163],
#         [ 70, 123, 163],
#         [ 70, 123, 163],
#         ...,
#         [ 54, 121, 174],
#         [ 54, 121, 174],
#         [ 54, 121, 174]],
#
#        ...,
#
#        [[185, 187, 176],
#         [186, 188, 177],
#         [188, 190, 179],
#         ...,
#         [199, 199, 187],
#         [196, 196, 184],
#         [193, 193, 181]],
#
#        [[199, 203, 189],
#         [197, 201, 187],
#         [194, 198, 184],
#         ...,
#         [207, 207, 195],
#         [201, 201, 189],
#         [201, 201, 189]],
#
#        [[193, 197, 183],
#         [192, 196, 182],
#         [189, 193, 179],
# ...

# %%
Image()

# %%
a = np.random.randn(3, 4)

# %%
a

# %%
pickle.loads(a.dumps())

# %%
marshal.dumps(a)

# %%
pickle.dumps(a)

# %%
dj.blob.unpack(dj.blob.pack(a))
