# %%
# %matplotlib inline

# %%
import datajoint as dj

# %%
dj.list_schemas()
# Out:
# Connecting dimitri@localhost:3306
# ['dimitri_alter',
#  'dimitri_attach',
#  'dimitri_blob',
#  'dimitri_blobs',
#  'dimitri_filepath',
#  'dimitri_nphoton',
#  'dimitri_nwb',
#  'dimitri_schema',
#  'dimitri_test',
#  'dimitri_tutorial',
#  'dimitri_university',
#  'dimitri_uuid',
#  'test_attach',
#  'test_external',
#  'test_filepath',
#  'test_graphs',
#  'test_graphs_external',
#  'test_graps',
#  'test_mikkel',
#  'test_orders',
#  'test_parse',
#  'test_question001',
#  'test_question002',
#  'university']

# %%
import datajoint as dj
schema = dj.schema('university')
schema.spawn_missing_classes()

# %%
dj.ERD(schema)

# %%
dj.U().aggr(Student(), n='count(*)')
# Out:
# n
# +------+
# 8000
#  (Total: 1)

# %%
dj.U('birth_year').aggr(Student.proj(birth_year='year(date_of_birth)'), n='count(*)').make_sql()
# Out:
# 'SELECT `birth_year`,count(*) as `n` FROM (SELECT `student_id`,year(date_of_birth) as `birth_year` FROM `university`.`student`) as `_s8` GROUP  BY `birth_year`'

# %%
Student.describe();
# Out:
# student_id           : int unsigned                 # university-wide ID number
# ---
# first_name           : varchar(40)
# last_name            : varchar(40)
# sex                  : enum('F','M','U')
# date_of_birth        : date
# home_address         : varchar(120)                 # mailing street address
# home_city            : varchar(60)                  # mailing address
# home_state           : char(2)                      # US state acronym: e.g. OH
# home_zip             : char(10)                     # zipcode e.g. 93979-4979
# home_phone           : varchar(20)                  # e.g. 414.657.6883x0881

# %%
dj.ERD(schema)

# %%
dj.U().aggr(Student, n='count(*)')
# Out:
# n
# +------+
# 8000
#  (Total: 1)

# %%
StudentMajor()
# Out:
# *student_id    dept     declare_date
# +------------+ +------+ +------------+
# 1000           CS       2014-07-25
# 1001           CS       2001-03-22
# 1002           MATH     2005-09-20
# 1004           BIOL     2011-11-03
# 1006           MATH     2002-05-13
# 1008           BIOL     2003-03-22
# 1010           BIOL     2015-12-23
# 1011           MATH     2007-02-04
# 1012           MATH     2007-10-30
# 1014           BIOL     2008-07-07
# 1016           PHYS     2014-07-13
# 1017           PHYS     1999-05-16
#    ...
#  (Total: 5986)

# %%
LetterGrade.aggr(Grade & CurrentTerm & 'dept="MATH"', n='count(*)')

dj.U('grade').aggr(Grade & CurrentTerm & 'dept="MATH"', n='count(*)')
# Out:
# *grade    n
# +-------+ +----+
# A         21
# A-        13
# B         18
# B+        18
# B-        13
# C         23
# C+        19
# C-        15
# D         17
# D+        24
# F         10
#  (Total: 11)

# %% [markdown]
# # Example queries

# %% [markdown]
# ## Restriction

# %%
# Students from Texas
Student & {'home_state': 'TX'}
Student & 'home_state="TX"'
# Out:
# *student_id    first_name     last_name     sex     date_of_birth  home_address   home_city      home_state     home_zip     home_phone
# +------------+ +------------+ +-----------+ +-----+ +------------+ +------------+ +------------+ +------------+ +----------+ +------------+
# 1088           Michael        Evans         M       1997-04-17     953 Chapman Un North Mary     TX             51230        743.474.8901x8
# 1101           Kevin          Morgan        M       2001-07-27     23085 James Fo Michaelborough TX             97544        001-236-918-27
# 1102           Terri          Webb          F       2003-12-11     431 Bailey Tra South Bobbyton TX             83165        +1-303-062-393
# 1257           Wendy          Diaz          F       1987-04-26     34554 Nelson O North Kaitlin  TX             13509        +1-485-069-289
# 1484           Audrey         Mcclure       F       1985-08-30     2728 Hester Sq Hessstad       TX             26456        366.826.0048x6
# 1530           James          Singleton     M       2002-08-01     729 Shane Alle Lake Brianview TX             89562        001-381-059-59
# 1668           Amanda         Johnson       F       1990-12-02     3976 Lawrence  Toddberg       TX             13676        +1-318-565-525
# 1846           Katherine      Anderson      F       1996-07-10     6885 Snyder Vi East Christina TX             04367        +1-599-516-193
# 2006           Philip         Rowe          M       1998-02-19     2421 Mahoney S East Mary      TX             89257        383.885.4312
# 2068           Angel          Payne         F       2000-05-23     5011 Pacheco O Lake Pamela    TX             25531        (734)845-7941x
# 2077           Erika          Reed          F       1992-02-24     6648 Long Circ Haroldland     TX             08033        (861)283-6330x
# 2164           Rebekah        Clayton       F       1997-08-27     58641 Wilson R Dianeburgh     TX             10916        238-207-7236x3
#    ...
#  (Total: 136)

# %%
# Male students from outside Texas
(Student & 'sex="M"')- {'home_state': 'TX'}
# Out:
# *student_id    first_name     last_name     sex     date_of_birth  home_address   home_city      home_state     home_zip     home_phone
# +------------+ +------------+ +-----------+ +-----+ +------------+ +------------+ +------------+ +------------+ +----------+ +------------+
# 1003           Steven         Mcfarland     M       1986-08-22     1943 Wilson Ra West Frankshir SC             75066        191.147.4845x0
# 1005           Sean           Brown         M       1987-01-28     02529 Barrett  Port Tina      KS             25576        0279163795
# 1008           Jeremiah       Simpson       M       1990-05-09     435 Brandi All Stephaniestad  GA             38681        1163736312
# 1011           Jonathan       Chapman       M       1993-09-13     70066 Clark Gr Jeffersonmouth MA             78208        (885)100-6173
# 1012           Anthony        Garrett       M       1988-12-09     4117 Richardso Debraville     AZ             03842        001-784-170-50
# 1013           Ronald         Cooke         M       1996-10-18     13997 Smith Pi Downsmouth     GA             48925        001-404-945-98
# 1015           Jack           Thompson      M       1991-10-19     5503 Davis Orc North James    CO             27222        509.914.3806x5
# 1018           Ryan           Powell        M       1996-12-30     730 Jordan Cor East Clairevil WA             49078        436-065-9072x2
# 1019           Mr.            Brandon       M       1991-05-11     75781 Jennifer Danielview     KS             28644        562-513-6912x7
# 1021           Stanley        Hines         M       1990-08-28     97582 Linda Gl Jonville       HI             11127        767-270-2501x9
# 1023           Daniel         Sullivan      M       1994-02-23     92930 Jonathan Loriberg       MN             76563        3075152971
# 1026           Albert         Gonzalez      M       1997-12-14     12055 Bishop G Bridgetborough GA             61448        (855)850-4792x
#    ...
#  (Total: 3952)

# %%
# Male students from outside Texas
Student & {'sex="M" and home_state <> "TX"'}
(Student & {'sex':"M"}) - {'home_state': "TX"}
# Out:
# *student_id    first_name     last_name     sex     date_of_birth  home_address   home_city      home_state     home_zip     home_phone
# +------------+ +------------+ +-----------+ +-----+ +------------+ +------------+ +------------+ +------------+ +----------+ +------------+
# 1003           Steven         Mcfarland     M       1986-08-22     1943 Wilson Ra West Frankshir SC             75066        191.147.4845x0
# 1005           Sean           Brown         M       1987-01-28     02529 Barrett  Port Tina      KS             25576        0279163795
# 1008           Jeremiah       Simpson       M       1990-05-09     435 Brandi All Stephaniestad  GA             38681        1163736312
# 1011           Jonathan       Chapman       M       1993-09-13     70066 Clark Gr Jeffersonmouth MA             78208        (885)100-6173
# 1012           Anthony        Garrett       M       1988-12-09     4117 Richardso Debraville     AZ             03842        001-784-170-50
# 1013           Ronald         Cooke         M       1996-10-18     13997 Smith Pi Downsmouth     GA             48925        001-404-945-98
# 1015           Jack           Thompson      M       1991-10-19     5503 Davis Orc North James    CO             27222        509.914.3806x5
# 1018           Ryan           Powell        M       1996-12-30     730 Jordan Cor East Clairevil WA             49078        436-065-9072x2
# 1019           Mr.            Brandon       M       1991-05-11     75781 Jennifer Danielview     KS             28644        562-513-6912x7
# 1021           Stanley        Hines         M       1990-08-28     97582 Linda Gl Jonville       HI             11127        767-270-2501x9
# 1023           Daniel         Sullivan      M       1994-02-23     92930 Jonathan Loriberg       MN             76563        3075152971
# 1026           Albert         Gonzalez      M       1997-12-14     12055 Bishop G Bridgetborough GA             61448        (855)850-4792x
#    ...
#  (Total: 3952)

# %%
# Students from TX, OK, or NM
Student & [{'home_state':'OK'}, {'home_state':'NM'}, {'home_state':'TX'}] 
Student & [{'home_state': s} for s in ('OK','NM','TX')]
Student & 'home_state in ("OK", "NM", "TX")'
# Out:
# *student_id    first_name     last_name     sex     date_of_birth  home_address   home_city      home_state     home_zip     home_phone
# +------------+ +------------+ +-----------+ +-----+ +------------+ +------------+ +------------+ +------------+ +----------+ +------------+
# 1029           Tara           Miller        F       1991-06-03     32661 Perkins  Jennifercheste NM             15149        773.591.6188x4
# 1088           Michael        Evans         M       1997-04-17     953 Chapman Un North Mary     TX             51230        743.474.8901x8
# 1101           Kevin          Morgan        M       2001-07-27     23085 James Fo Michaelborough TX             97544        001-236-918-27
# 1102           Terri          Webb          F       2003-12-11     431 Bailey Tra South Bobbyton TX             83165        +1-303-062-393
# 1115           Nicole         Henderson     F       2000-04-29     4300 Peters Ra Alexandraland  NM             75466        594-853-4693
# 1153           Paul           Johnson       M       1998-03-29     570 Abigail Po Nguyenmouth    NM             91123        535.722.8469x4
# 1209           David          Riley         M       1993-06-17     940 Carlos Loa West Peter     OK             36897        001-803-025-19
# 1216           Cristian       Matthews      M       1992-04-27     24296 Cody For Kevinchester   OK             43632        (583)392-1447x
# 1217           Melissa        Howard        F       1997-11-30     0081 Wanda Pra Kaitlinton     OK             80580        001-665-334-39
# 1229           Matthew        Knight        M       1992-11-06     062 Julie Burg Ayersmouth     OK             61302        1661625766
# 1247           Christina      Daniel        F       1997-09-26     83145 Jacqueli Port Melissa   NM             66683        +1-317-129-217
# 1257           Wendy          Diaz          F       1987-04-26     34554 Nelson O North Kaitlin  TX             13509        +1-485-069-289
#    ...
#  (Total: 434)

# %%
(millenials - (Enroll & 'dept="MATH"')).make_sql()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-be1a5a021735> in <module>
# ----> 1 (millenials - (Enroll & 'dept="MATH"')).make_sql()
#
# NameError: name 'millenials' is not defined

# %%
# Millenials
millenials = Student & 'date_of_birth between "1981-01-01" and "1996-12-31"'

# %%
# Students who have taken classes
Student & Enroll

# %%
# Students who have not taken classes
Student - Enroll

# %%
# Students who have taken Biology classes but no MATH courses
(Student & (Enroll & 'dept="BIOL"')) - (Enroll & 'dept="MATH"')

# %%
# Students who have not selected a major
Student - StudentMajor

# %%
# Students who are taking courses in the current term
Student - (Enroll & CurrentTerm)

# %%
# Ungraded courses
Enroll - Grade

# %%
# Ungraded courses in the current term
(Enroll & CurrentTerm) - Grade

# %%
# Students who have taken classes and have chosen a major
(Student & Enroll & StudentMajor).fetch(as_dict=True)

# %%
#Students who have taken classes or have chosen a major
Student & [Enroll, StudentMajor]

# %%
# Enrollment in courses from the same department as the students' major
Enroll & StudentMajor

# %% [markdown]
# ## Join

# %%
# Grade point values
Grade * LetterGrade

# %%
# Graded enrollments with complete course and student information
Student * Enroll * Course * Section * Grade * LetterGrade

# %%
# Students with ungraded courses in current term
Student & (Enroll * CurrentTerm - Grade)

# %%
# Enrollments before students' date of birth
Student * Enroll & 'term_year <= date_of_birth'

# %% [markdown]
# ## Proj

# %%
# remove student personal info other than home state and sex
Student.proj('home_state', 'sex')

# %%
# Student major
Student.proj('first_name','last_name')*StudentMajor.proj(major='dept')

# %%
# Enrollment with major information
Enroll * StudentMajor.proj(major='dept')

# %%
# Enrollment outside chosen major
Enroll * StudentMajor.proj(major='dept') & 'major<>dept'

# %%
# Enrollment not matching major 
Enroll - StudentMajor

# %%
# Total grade points
(Course * Grade * LetterGrade).proj(total='points*credits')

# %% [markdown]
# ## Aggr

# %%
dj.U().aggr(Student(), n='count(*)')

# %%
# Students in each section
Section.aggr(Enroll, n='count(*)')

# %%
# Average grade in each course
Course.aggr(Grade*LetterGrade, avg_grade='avg(points)')

# %%
# Fraction graded in each section
(Section.aggr(Enroll,n='count(*)') * Section.aggr(Grade, m='count(*)')).proj(
    'm','n',frac='m/n')

# %%
# GPA
Student.aggr(Course * Grade * LetterGrade, 
             gpa='sum(points*credits)/sum(credits)')

# %%
# GPA in current Term
Student.aggr(Course * Grade * LetterGrade & CurrentTerm, 
             gpa='sum(points*credits)/sum(credits)')

# %%
# Average GPA for each major
gpa = Student.aggr(Course * Grade * LetterGrade,
                   gpa='sum(points*credits)/sum(credits)')
Department.aggr(StudentMajor*gpa, avg_gpa='avg(gpa)')

# %% [markdown]
# ## Relation U

# %%
# All home states
dj.U('home_state').aggr(Student, n='count(*)')

# %%
# Unique last names
dj.U('last_name') & Student

# %%
# Number of students from each state by gender
dj.U('home_state', 'sex').aggr(Student, n='count(*)')

# %%
# GPA by sex
dj.U('sex').aggr(Student*gpa, avg_gpa ='avg(gpa)')

# %%
# Sex ratio for gender neutral names
(dj.U('first_name').aggr(Student, percent_male='100*avg(sex="M")'
                       ) & 'percent_male > 0 and percent_male < 100').make_sql()

# %%
# Students with the same birthdays
s1 = Student.proj('date_of_birth', s1='student_id') * dj.U('date_of_birth')
s2 = Student.proj('date_of_birth', s2='student_id') * dj.U('date_of_birth')
s1 * s2 & 's1 < s2'

# %%
dj.U().aggr(Student(), n='count(*)')
